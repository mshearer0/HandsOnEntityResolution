# %% [markdown]
# # Chapter 5 - Matching At Scale

# %% [markdown]
# ## Step 1 - Data Acquisition

# %% [markdown]
# ### Wikipedia

# %%
import requests
import json
import zipfile
import io
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
# Get the Wikipedia webpage and find all tables.

url = "https://en.wikipedia.org/wiki/List_of_MPs_elected_in_the_2019_United_Kingdom_general_election"

website_page = requests.get(url).text
soup = BeautifulSoup(website_page,'html.parser')
tables = soup.find_all('table')

# %%
# Find the table with members returned, extract rows as a list of lists and load into dataframe

for table in tables:
    if 'Member returned' in table.text:
        headers = [header.text.strip() for header in table.find_all('th')]
        headers = headers[:5]
        dfrows = []
        table_rows = table.find_all('tr')    
        for row in table_rows:
            td = row.find_all('td')
            dfrow = []
            for element in td:
                if element.text!='\n':
                    dfrow.append(element.text)
                if element.select("a[class='image']"):
                    for link in element.select("a[title]"):
                        urltail = link['href']
                        url = f'https://en.wikipedia.org{urltail}'
            dfrow.append(url)
            dfrows.append(dfrow)
        headers.append('Wikilink')
df_w = pd.DataFrame(dfrows, columns=headers)
df_w = df_w.dropna()

# %%
def get_bday(url):
    wiki_page = requests.get(url).text
    soup = BeautifulSoup(wiki_page,'html.parser')
    bday = ''
    bdayelement = soup.select_one("span[class='bday']")
    if bdayelement is not None:
        bday = bdayelement.text
    return(bday)

# %%
df_w['Birthday'] = df_w.apply(lambda x: get_bday(x.Wikilink), axis=1)

# %%
df_w.head(n=5)
# Out:
#            Constituency Party of incumbentbefore election    Member returned  \
# 1            Aberavon\n                          Labour\n  Stephen Kinnock\n
# 2           Aberconwy\n                    Conservative\n     Robin Millar\n
# 3      Aberdeen North\n               Scottish National\n  Kirsty Blackman\n
# 4      Aberdeen South\n                    Conservative\n    Stephen Flynn\n
# 5  Airdrie and Shotts\n               Scottish National\n        Neil Gray\n
#
#   Party of incumbentafter election  \
# 1                         Labour\n
# 2                   Conservative\n
# 3              Scottish National\n
# 4              Scottish National\n
# 5              Scottish National\n
#
#                                                Notes  \
# 1                                        Seat held\n
# 2     Previous incumbent, Guto Bebb, did not stand\n
# 3                                        Seat held\n
# 4  Previous incumbent, Ross Thomson, did not stand\n
# 5                                        Seat held\n
#
#                                             Wikilink    Birthday
# 1      https://en.wikipedia.org/wiki/Stephen_Kinnock  1970-01-01
# 2  https://en.wikipedia.org/wiki/Robin_Millar_(po...  1968-10-15
# 3      https://en.wikipedia.org/wiki/Kirsty_Blackman  1986-03-20
# 4  https://en.wikipedia.org/wiki/Stephen_Flynn_(S...  1988-10-13
# 5            https://en.wikipedia.org/wiki/Neil_Gray  1986-03-16

# %% [markdown]
# ### Companies House Persons of Significant Control

# %%
# UK Companies House Persons with Significant Control Download Page

url = "http://download.companieshouse.gov.uk/en_pscdata.html"

# %%
# Download snapshots, convert json to dataframe, remove unwanted columns and append to a single dataframe
# Ignore last file 23of23

df_psctotal = pd.DataFrame()
with requests.Session() as req:
        r = req.get(url)
        soup = BeautifulSoup(r.content, 'html.parser')
        snapshots = [f"{url[:38]}{item['href']}" for item in soup.select(
            "a[href*='psc-snapshot']")]
        for snapshot in snapshots:    
            response = requests.get(snapshot).content     
            zipsnapshot = zipfile.ZipFile(io.BytesIO(response))
            if(zipsnapshot.namelist()[0][-10:] != "23of23.txt"):
                tempfile = zipsnapshot.extract(zipsnapshot.namelist()[0])
                print(zipsnapshot.namelist()[0])
                df_psc = pd.json_normalize(pd.Series(open(tempfile, encoding="utf8").readlines()).apply(json.loads))
                df_psc = df_psc.dropna(subset=['data.name_elements.forename'])
                df_psc = df_psc[['company_number','data.name_elements.surname','data.name_elements.forename','data.date_of_birth.month','data.date_of_birth.year']]  
                df_psctotal = pd.concat([df_psctotal, df_psc], ignore_index=True)
# Out:
# psc-snapshot-2023-04-12_1of23.txt
# psc-snapshot-2023-04-12_2of23.txt
# psc-snapshot-2023-04-12_3of23.txt
# psc-snapshot-2023-04-12_4of23.txt
# psc-snapshot-2023-04-12_5of23.txt
# psc-snapshot-2023-04-12_6of23.txt
# psc-snapshot-2023-04-12_7of23.txt
# psc-snapshot-2023-04-12_8of23.txt
# psc-snapshot-2023-04-12_9of23.txt
# psc-snapshot-2023-04-12_10of23.txt
# psc-snapshot-2023-04-12_11of23.txt
# psc-snapshot-2023-04-12_12of23.txt
# psc-snapshot-2023-04-12_13of23.txt
# psc-snapshot-2023-04-12_14of23.txt
# psc-snapshot-2023-04-12_15of23.txt
# psc-snapshot-2023-04-12_16of23.txt
# psc-snapshot-2023-04-12_17of23.txt
# psc-snapshot-2023-04-12_18of23.txt
# psc-snapshot-2023-04-12_19of23.txt
# psc-snapshot-2023-04-12_20of23.txt
# psc-snapshot-2023-04-12_21of23.txt
# psc-snapshot-2023-04-12_22of23.txt

# %% [markdown]
# ### Saving to Local Storage

# %%
#df_w.to_csv('mps_wiki_bday_raw.csv', index=False)
df_w = pd.read_csv('mps_wiki_bday_raw.csv')
#df_psctotal.to_csv('psc_raw.csv')
df_psc = pd.read_csv('psc_raw.csv', dtype={'data.name_elements.surname':'string','data.name_elements.forename':'string'})

# %% [markdown]
# ## Step 2 - Data Standardization

# %% [markdown]
# ### Wikipedia

# %%
df_w = df_w.dropna()
df_w['Year'] = pd.to_datetime(df_w['Birthday']).dt.year.astype('int64')
df_w['Month'] = pd.to_datetime(df_w['Birthday']).dt.month.astype('int64')

# %%
df_w = df_w.rename(columns={ 'Member returned' : 'Fullname'})
df_w['Fullname'] = df_w['Fullname'].str.rstrip("\n")
df_w['Fullname'] = df_w['Fullname'].str.lstrip("\n")
df_w['Firstname'] = df_w['Fullname'].str.split().str[0]
df_w['Lastname'] = df_w['Fullname'].astype(str).apply(lambda x: ' '.join(x.split()[1:]))

# %%
df_w['unique_id'] = df_w.index
df_w["company_number"] = np.nan
df_w=df_w[['Firstname','Lastname','Month','Year','unique_id','company_number']]

# %%
df_w.head(n=5)
# Out:
#   Firstname  Lastname  Month  Year  unique_id  company_number
# 0   Stephen   Kinnock      1  1970          0             NaN
# 1     Robin    Millar     10  1968          1             NaN
# 2    Kirsty  Blackman      3  1986          2             NaN
# 3   Stephen     Flynn     10  1988          3             NaN
# 4      Neil      Gray      3  1986          4             NaN

# %% [markdown]
# ### Companies House Persons of Significant Control

# %%
# Rename and convert columns for matching

df_psc = df_psc.dropna()

df_psc['Year'] = df_psc['data.date_of_birth.year'].astype('int64')
df_psc['Month'] = df_psc['data.date_of_birth.month'].astype('int64')
df_psc['Firstname']=df_psc['data.name_elements.forename']
df_psc['Lastname']=df_psc['data.name_elements.surname']

# Create unique index column needed by Splink from dataframe index
# Subset down to required columns

df_psc['unique_id'] = df_psc.index
df_psc = df_psc[['Lastname','Firstname','company_number','Year','Month','unique_id']]

# %% [markdown]
# ### Saving to Local Storage

# %%
#df_w.to_csv('mps_wiki_bday_clean.csv', index=False)
df_w = pd.read_csv('mps_wiki_bday_clean.csv')
#df_psc.to_csv('psc_clean.csv', index=False)
df_psc = pd.read_csv('psc_clean.csv')

# %% [markdown]
# # Step 3 - Record Blocking and Attribute Comparison

# %%
len(df_psc)
# Out:
# 9956208

# %%
# Count of simple merge on matching Year and Month 

df_mp = df_w.merge(df_psc, on=['Year','Month'], suffixes=('_w', '_psc'))
len(df_mp)
# Out:
# 10891131

# %%
# Calculate exact match using a simple join

df_result = df_w.merge(df_psc, on=['Lastname','Firstname','Year','Month'], suffixes=('_w', '_psc'))
df_result
# Out:
#     Firstname   Lastname  Month  Year  unique_id_w  company_number_w  \
# 0       Robin     Millar     10  1968            1               NaN
# 1       Robin     Millar     10  1968            1               NaN
# 2         Leo   Docherty     10  1976            5               NaN
# 3       Wendy     Morton     11  1967            6               NaN
# 4      Graham      Brady      5  1967            7               NaN
# ..        ...        ...    ...   ...          ...               ...
# 257      Mark  Jenkinson      1  1982          638               NaN
# 258      Mark  Jenkinson      1  1982          638               NaN
# 259    Steven      Baker      6  1971          642               NaN
# 260      Mark    Garnier      2  1963          644               NaN
# 261    Marcus       Fysh     11  1970          646               NaN
#
#     company_number_psc  unique_id_psc
# 0             04569484        1231331
# 1             06975241        4255139
# 2             08204196         621947
# 3             02715837        3297130
# 4             07484717        6535629
# ..                 ...            ...
# 257           10791041        3537960
# 258           12131090        5998989
# 259           07355501         234561
# 260           13636383        8245158
# 261           08569809        4113673
#
# [262 rows x 8 columns]

# %%
# Splink settings to block on year and month matches and then compare First and Last names

from splink.duckdb.duckdb_linker import DuckDBLinker
from splink.duckdb import duckdb_comparison_library as cl
settings = {
    "link_type": "link_only",
    "blocking_rules_to_generate_predictions": [
        "l.year = r.year and l.month = r.month"
    ],
    "comparisons": [
        cl.jaro_winkler_at_thresholds("Firstname", [0.9]),
        cl.jaro_winkler_at_thresholds("Lastname", [0.9]),
        cl.exact_match("Month"),
        cl.exact_match("Year", term_frequency_adjustments=True),
    ],       
}

# %%
# Setup linker and profile columns

linker = DuckDBLinker([df_w, df_psc], settings, input_table_aliases=["df_w", "df_psc"])
linker.profile_columns(["Firstname","Lastname","Month","Year"], top_n=10, bottom_n=5)
# Out:
# <div id="altair-viz-8775fa73278b4bd09e5a502b3c1d4b96"></div>
# <script type="text/javascript">
#   var VEGA_DEBUG = (typeof VEGA_DEBUG == "undefined") ? {} : VEGA_DEBUG;
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-8775fa73278b4bd09e5a502b3c1d4b96") {
#       outputDiv = document.getElementById("altair-viz-8775fa73278b4bd09e5a502b3c1d4b96");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.17.0?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function maybeLoadScript(lib, version) {
#       var key = `${lib.replace("-", "")}_version`;
#       return (VEGA_DEBUG[key] == version) ?
#         Promise.resolve(paths[lib]) :
#         new Promise(function(resolve, reject) {
#           var s = document.createElement('script');
#           document.getElementsByTagName("head")[0].appendChild(s);
#           s.async = true;
#           s.onload = () => {
#             VEGA_DEBUG[key] = version;
#             return resolve(paths[lib]);
#           };
#           s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#           s.src = paths[lib];
#         });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else {
#       maybeLoadScript("vega", "5")
#         .then(() => maybeLoadScript("vega-lite", "4.17.0"))
#         .then(() => maybeLoadScript("vega-embed", "6"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300}}, "vconcat": [{"hconcat": [{"data": {"values": [{"percentile_ex_nulls": 0.9793885350227356, "percentile_inc_nulls": 0.9793885350227356, "value_count": 205225, "group_name": "Firstname", "total_non_null_rows": 9956843, "total_rows_inc_nulls": 9956843, "sum_tokens_in_value_count_group": 205225.0, "distinct_value_count": 301043}, {"percentile_ex_nulls": 0.9642545580863953, "percentile_inc_nulls": 0.9642545580863953, "value_count": 150687, "group_name": "Firstname", "total_non_null_rows": 9956843, "total_rows_inc_nulls": 9956843, "sum_tokens_in_value_count_group": 150687.0, "distinct_value_count": 301043}, {"percentile_ex_nulls": 0.9493234753608704, "percentile_inc_nulls": 0.9493234753608704, "value_count": 148666, "group_name": "Firstname", "total_non_null_rows": 9956843, "total_rows_inc_nulls": 9956843, "sum_tokens_in_value_count_group": 148666.0, "distinct_value_count": 301043}, {"percentile_ex_nulls": 0.9345048666000366, "percentile_inc_nulls": 0.9345048666000366, "value_count": 147547, "group_name": "Firstname", "total_non_null_rows": 9956843, "total_rows_inc_nulls": 9956843, "sum_tokens_in_value_count_group": 147547.0, "distinct_value_count": 301043}, {"percentile_ex_nulls": 0.9201902747154236, "percentile_inc_nulls": 0.9201902747154236, "value_count": 142528, "group_name": "Firstname", "total_non_null_rows": 9956843, "total_rows_inc_nulls": 9956843, "sum_tokens_in_value_count_group": 142528.0, "distinct_value_count": 301043}, {"percentile_ex_nulls": 0.9070367217063904, "percentile_inc_nulls": 0.9070367217063904, "value_count": 130968, "group_name": "Firstname", "total_non_null_rows": 9956843, "total_rows_inc_nulls": 9956843, "sum_tokens_in_value_count_group": 130968.0, "distinct_value_count": 301043}, {"percentile_ex_nulls": 0.8947978019714355, "percentile_inc_nulls": 0.8947978019714355, "value_count": 121861, "group_name": "Firstname", "total_non_null_rows": 9956843, "total_rows_inc_nulls": 9956843, "sum_tokens_in_value_count_group": 121861.0, "distinct_value_count": 301043}, {"percentile_ex_nulls": 0.8837204575538635, "percentile_inc_nulls": 0.8837204575538635, "value_count": 110295, "group_name": "Firstname", "total_non_null_rows": 9956843, "total_rows_inc_nulls": 9956843, "sum_tokens_in_value_count_group": 110295.0, "distinct_value_count": 301043}, {"percentile_ex_nulls": 0.873125433921814, "percentile_inc_nulls": 0.873125433921814, "value_count": 105493, "group_name": "Firstname", "total_non_null_rows": 9956843, "total_rows_inc_nulls": 9956843, "sum_tokens_in_value_count_group": 105493.0, "distinct_value_count": 301043}, {"percentile_ex_nulls": 0.862744927406311, "percentile_inc_nulls": 0.862744927406311, "value_count": 103357, "group_name": "Firstname", "total_non_null_rows": 9956843, "total_rows_inc_nulls": 9956843, "sum_tokens_in_value_count_group": 103357.0, "distinct_value_count": 301043}, {"percentile_ex_nulls": 0.8528159856796265, "percentile_inc_nulls": 0.8528159856796265, "value_count": 98861, "group_name": "Firstname", "total_non_null_rows": 9956843, "total_rows_inc_nulls": 9956843, "sum_tokens_in_value_count_group": 98861.0, "distinct_value_count": 301043}, {"percentile_ex_nulls": 0.8429365754127502, "percentile_inc_nulls": 0.8429365754127502, "value_count": 98368, "group_name": "Firstname", "total_non_null_rows": 9956843, "total_rows_inc_nulls": 9956843, "sum_tokens_in_value_count_group": 98368.0, "distinct_value_count": 301043}, {"percentile_ex_nulls": 0.8342543840408325, "percentile_inc_nulls": 0.8342543840408325, "value_count": 86447, "group_name": "Firstname", "total_non_null_rows": 9956843, "total_rows_inc_nulls": 9956843, "sum_tokens_in_value_count_group": 86447.0, "distinct_value_count": 301043}, {"percentile_ex_nulls": 0.8268038034439087, "percentile_inc_nulls": 0.8268038034439087, "value_count": 74184, "group_name": "Firstname", "total_non_null_rows": 9956843, "total_rows_inc_nulls": 9956843, "sum_tokens_in_value_count_group ...

# %%
# Estimate u values

linker.estimate_u_using_random_sampling(target_rows=1e7)
# Out:
# ----- Estimating u probabilities using random sampling -----
#
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - Firstname (no m values are trained).
#     - Lastname (no m values are trained).
#     - Month (no m values are trained).
#     - Year (no m values are trained).

# %%
## Calculate m values 

linker.estimate_parameters_using_expectation_maximisation("l.Lastname = r.Lastname and l.Month = r.Month")
linker.estimate_parameters_using_expectation_maximisation("l.Firstname = r.Firstname and  l.Year = r.Year")
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l.Lastname = r.Lastname and l.Month = r.Month
#
# Parameter estimates will be made for the following comparison(s):
#     - Firstname
#     - Year
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - Lastname
#     - Month
#
# Iteration 1: Largest change in params was 0.041 in the m_probability of Year, level `Exact match`
# Iteration 2: Largest change in params was 0.00503 in the m_probability of Year, level `Exact match`
# Iteration 3: Largest change in params was 0.00472 in the m_probability of Firstname, level `Jaro_winkler_similarity >= 0.9`
# Iteration 4: Largest change in params was 0.00591 in the m_probability of Firstname, level `Jaro_winkler_similarity >= 0.9`
# Iteration 5: Largest change in params was -0.00532 in the m_probability of Firstname, level `Exact match`
# Iteration 6: Largest change in params was -0.00387 in the m_probability of Firstname, level `Exact match`
# Iteration 7: Largest change in params was -0.00244 in the m_probability of Firstname, level `Exact match`
# Iteration 8: Largest change in params was -0.00142 in the m_probability of Firstname, level `Exact match`
# Iteration 9: Largest change in params was -0.00079 in the m_probability of Firstname, level `Exact match`
# Iteration 10: Largest change in params was -0.000438 in the m_probability of Firstname, level `Exact match`
# Iteration 11: Largest change in params was -0.000249 in the m_probability of Firstname, level `Exact match`
# Iteration 12: Largest change in params was -0.000151 in the m_probability of Firstname, level `Exact match`
# Iteration 13: Largest change in params was -0.0001 in the m_probability of Firstname, level `Exact match`
#
# EM converged after 13 iterations
#
# Your model is not yet fully trained. Missing estimates for:
#     - Lastname (no m values are trained).
#     - Month (no m values are trained).
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l.Firstname = r.Firstname and  l.Year = r.Year
#
# Parameter estimates will be made for the following comparison(s):
#     - Lastname
#     - Month
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - Firstname
#     - Year
#
# Iteration 1: Largest change in params was 0.0257 in the m_probability of Month, level `Exact match`
# Iteration 2: Largest change in params was 0.0191 in the m_probability of Lastname, level `Jaro_winkler_similarity >= 0.9`
# Iteration 3: Largest change in params was 0.0322 in the m_probability of Lastname, level `Jaro_winkler_similarity >= 0.9`
# Iteration 4: Largest change in params was 0.0278 in the m_probability of Lastname, level `Jaro_winkler_similarity >= 0.9`
# Iteration 5: Largest change in params was -0.0343 in the m_probability of Month, level `Exact match`
# Iteration 6: Largest change in params was 0.0465 in the m_probability of Month, level `All other comparisons`
# Iteration 7: Largest change in params was -0.0565 in the m_probability of Month, level `Exact match`
# Iteration 8: Largest change in params was -0.0605 in the m_probability of Month, level `Exact match`
# Iteration 9: Largest change in params was 0.0575 in the m_probability of Month, level `All other comparisons`
# Iteration 10: Largest change in params was -0.0493 in the m_probability of Month, level `Exact match`
# Iteration 11: Largest change in params was 0.0395 in the m_probability of Month, level `All other comparisons`
# Iteration 12: Largest change in params was -0.0304 in the m_probability of Month, level `Exact match`
# Iteration 13: Largest change in params was -0.0231 in the m_probability of Month, level `Exact match`
# Iteration 14: Largest change in params was 0.0173 in the m_probability of Month, level `All other comparisons`
# Iteration 15: Largest change in params was -0.0128 in the m_probability of Month, level `Exact match`
# Iteration 16: Largest change in params was 0.00944 in the m_probability of Month, level `All other comparisons`
# Iteration 17: Largest change in params was 0.00687 in the m_probability of Month, level `All other comparisons`
# Iteration 18: Largest change in params was -0.00495 in the m_probability of Month, level `Exact match`
# Iteration 19: Largest change in params was -0.00353 in the m_probability of Month, level `Exact match`
# Iteration 20: Largest change in params was 0.00251 in the m_probability of Month, level `All other comparisons`
# Iteration 21: Largest change in params was -0.00177 in the m_probability of Month, level `Exact match`
# Iteration 22: Largest change in params was -0.00124 in the m_probability of Month, level `Exact match`
# Iteration 23: Largest change in params was -0.000873 in the m_probability of Month, level `Exact match`
# Iteration 24: Largest change in params was 0.000611 in the m_probability of Month, level `All other comparisons`
# Iteration 25: Largest change in params was 0.000427 in the m_probability of Month, level `All other comparisons`
#
# EM converged after 25 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values
# <EMTrainingSession, blocking on l.Firstname = r.Firstname and  l.Year = r.Year, deactivating comparisons Firstname, Year>

# %%
linker.match_weights_chart()
# Out:
# <div id="altair-viz-46de40cb118c482bb7ad7c4db6bc9373"></div>
# <script type="text/javascript">
#   var VEGA_DEBUG = (typeof VEGA_DEBUG == "undefined") ? {} : VEGA_DEBUG;
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-46de40cb118c482bb7ad7c4db6bc9373") {
#       outputDiv = document.getElementById("altair-viz-46de40cb118c482bb7ad7c4db6bc9373");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.17.0?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function maybeLoadScript(lib, version) {
#       var key = `${lib.replace("-", "")}_version`;
#       return (VEGA_DEBUG[key] == version) ?
#         Promise.resolve(paths[lib]) :
#         new Promise(function(resolve, reject) {
#           var s = document.createElement('script');
#           document.getElementsByTagName("head")[0].appendChild(s);
#           s.async = true;
#           s.onload = () => {
#             VEGA_DEBUG[key] = version;
#             return resolve(paths[lib]);
#           };
#           s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#           s.src = paths[lib];
#         });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else {
#       maybeLoadScript("vega", "5")
#         .then(() => maybeLoadScript("vega-lite", "4.17.0"))
#         .then(() => maybeLoadScript("vega-embed", "6"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"width": 400, "height": 60}, "mark": {"tooltip": null}, "title": {"anchor": "middle"}, "header": {"title": null}}, "data": {"values": [{"comparison_name": "probability_two_random_records_match", "sql_condition": null, "label_for_charts": "", "m_probability": null, "u_probability": null, "m_probability_description": null, "u_probability_description": null, "has_tf_adjustments": false, "tf_adjustment_column": null, "tf_adjustment_weight": null, "is_null_level": false, "bayes_factor": 0.00010001000100010001, "log2_bayes_factor": -13.287568102831404, "comparison_vector_value": 0, "max_comparison_vector_value": 0, "bayes_factor_description": "The probability that two random records drawn at random match is 0.000 or one in  10,000.0 records.This is equivalent to a starting match weight of -13.288.", "probability_two_random_records_match": 0.0001, "comparison_sort_order": -1}, {"comparison_name": "Firstname", "sql_condition": "\"Firstname_l\" = \"Firstname_r\"", "label_for_charts": "Exact match", "m_probability": 0.9602685306508039, "u_probability": 0.005485070883942435, "m_probability_description": "Amongst matching record comparisons, 96.03% of records are in the exact match comparison level", "u_probability_description": "Amongst non-matching record comparisons, 0.55% of records are in the exact match comparison level", "has_tf_adjustments": false, "tf_adjustment_column": null, "tf_adjustment_weight": 1.0, "is_null_level": false, "bayes_factor": 175.06948423620076, "log2_bayes_factor": 7.45178382421554, "comparison_vector_value": 2, "max_comparison_vector_value": 2, "bayes_factor_description": "If comparison level is `exact match` then comparison is 175.07 times more likely to be a match", "probability_two_random_records_match": 0.0001, "comparison_sort_order": 0}, {"comparison_name": "Firstname", "sql_condition": "jaro_winkler_similarity(\"Firstname_l\", \"Firstname_r\") >= 0.9", "label_for_charts": "Jaro_winkler_similarity >= 0.9", "m_probability": 0.036033999740055486, "u_probability": 0.0015283955684410712, "m_probability_description": "Amongst matching record comparisons, 3.60% of records are in the jaro_winkler_similarity >= 0.9 comparison level", "u_probability_description": "Amongst non-matching record comparisons, 0.15% of records are in the jaro_winkler_similarity >= 0.9 comparison level", "has_tf_adjustments": false, "tf_adjustment_column": null, "tf_adjustment_weight": 1.0, "is_null_level": false, "bayes_factor": 23.576357118602058, "log2_bayes_factor": 4.559268913589421, "comparison_vector_value": 1, "max_comparison_vector_value": 2, "bayes_factor_description": "If comparison level is `jaro_winkler_similarity >= 0.9` then comparison is 23.58 times more likely to be a match", "probability_two_random_records_match": 0.0001, "comparison_sort_order": 0}, {"comparison_name": "Firstname", "sql_condition": "ELSE", "label_for_charts": "All other comparisons", "m_probability": 0.0036974696091406347, "u_probability": 0.9929865335476165, "m_probability_description": "Amongst matching record comparisons, 0.37% of records are in the all other comparisons comparison level", "u_probability_description": "Amongst non-matching record comparisons, 99.30% of records are in the all other comparisons comparison level", "has_tf_adjustments": false, "tf_adjustment_column": null, "tf_adjustment_weight": 1.0, "is_null_level": false, "bayes_factor": 0.003723584846544478, "log2_bayes_factor": -8.069092053123875, "comparison_vector_value": 0, "max_comparison_vector_value": 2, "bayes_factor_description": "If comparison level is `all other comparisons` then comparison is  268.56 times less likely to be a match", "probability_two_random_records_match": 0.0001, "comparison_sort_order": 0}, {"comparison_name": "Lastname", "sql_condition": "\"Lastname_l\" = \"Lastname_r\"", "label_for_charts": "Exact match", "m_probability": 0.7333579292596545, "u_probability": 0.00047180580292986897, "m_probability_description": "Amongst mat ...

# %%
linker.m_u_parameters_chart()
# Out:
# <div id="altair-viz-67731fefe184468eaccae88855a9bab3"></div>
# <script type="text/javascript">
#   var VEGA_DEBUG = (typeof VEGA_DEBUG == "undefined") ? {} : VEGA_DEBUG;
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-67731fefe184468eaccae88855a9bab3") {
#       outputDiv = document.getElementById("altair-viz-67731fefe184468eaccae88855a9bab3");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.17.0?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function maybeLoadScript(lib, version) {
#       var key = `${lib.replace("-", "")}_version`;
#       return (VEGA_DEBUG[key] == version) ?
#         Promise.resolve(paths[lib]) :
#         new Promise(function(resolve, reject) {
#           var s = document.createElement('script');
#           document.getElementsByTagName("head")[0].appendChild(s);
#           s.async = true;
#           s.onload = () => {
#             VEGA_DEBUG[key] = version;
#             return resolve(paths[lib]);
#           };
#           s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#           s.src = paths[lib];
#         });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else {
#       maybeLoadScript("vega", "5")
#         .then(() => maybeLoadScript("vega-lite", "4.17.0"))
#         .then(() => maybeLoadScript("vega-embed", "6"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"width": 400, "height": 300}, "title": {"anchor": "middle", "offset": 10}, "header": {"title": null}}, "hconcat": [{"mark": "bar", "title": {"text": "Amongst matching record comparisons:", "fontWeight": "bold", "fontSize": 12}, "encoding": {"row": {"type": "nominal", "field": "comparison_name", "sort": {"field": "comparison_sort_order"}, "header": {"labelAngle": 0, "labelAnchor": "middle", "labelAlign": "left"}}, "x": {"type": "quantitative", "field": "m_probability", "axis": {"title": "Proportion of record comparisons"}}, "y": {"type": "nominal", "axis": {"title": null}, "field": "label_for_charts", "sort": {"field": "comparison_vector_value", "order": "descending"}}, "tooltip": [{"type": "nominal", "field": "m_probability_description", "title": "m probability description"}, {"type": "nominal", "field": "comparison_name", "title": "Comparison column name"}, {"type": "ordinal", "field": "label_for_charts", "title": "Label"}, {"type": "nominal", "field": "sql_condition", "title": "SQL condition"}, {"type": "quantitative", "field": "m_probability", "format": ".4p", "title": "m probability"}, {"type": "quantitative", "field": "u_probability", "format": ".4p", "title": "u probability"}, {"type": "quantitative", "field": "bayes_factor", "title": "Bayes factor = m/u", "format": ",.4f"}, {"type": "quantitative", "field": "log2_bayes_factor", "title": "Match weight = log2(m/u)", "format": ",.4f"}], "color": {"value": "green"}}, "resolve": {"scale": {"y": "independent"}}, "transform": [{"filter": "(datum.bayes_factor != 'no-op filter due to vega lite issue 4680')"}], "width": 150, "height": {"step": 12}}, {"mark": "bar", "title": {"text": "Amongst non-matching record comparisons:", "fontWeight": "bold", "fontSize": 12}, "encoding": {"row": {"type": "nominal", "field": "comparison_name", "sort": {"field": "comparison_sort_order"}, "header": {"labels": false}}, "x": {"type": "quantitative", "field": "u_probability", "axis": {"title": "Proportion of record comparisons"}}, "y": {"type": "nominal", "axis": {"title": null}, "field": "label_for_charts", "sort": {"field": "comparison_vector_value", "order": "descending"}}, "tooltip": [{"type": "nominal", "field": "u_probability_description", "title": "u probability description"}, {"type": "nominal", "field": "comparison_name", "title": "Comparison column name"}, {"type": "ordinal", "field": "label_for_charts", "title": "Label"}, {"type": "nominal", "field": "sql_condition", "title": "SQL condition"}, {"type": "quantitative", "field": "m_probability", "format": ".4p", "title": "m probability"}, {"type": "quantitative", "field": "u_probability", "format": ".4p", "title": "u probability"}, {"type": "quantitative", "field": "bayes_factor", "title": "Bayes factor = m/u", "format": ",.4f"}, {"type": "quantitative", "field": "log2_bayes_factor", "title": "Match weight = log2(m/u)", "format": ",.4f"}], "color": {"value": "red"}}, "resolve": {"scale": {"y": "independent"}}, "transform": [{"filter": "(datum.bayes_factor != 'no-op filter2 due to vega lite issue 4680')"}], "width": 150, "height": {"step": 12}}], "data": {"values": [{"comparison_name": "Firstname", "sql_condition": "\"Firstname_l\" = \"Firstname_r\"", "label_for_charts": "Exact match", "m_probability": 0.9602685306508039, "u_probability": 0.005485070883942435, "m_probability_description": "Amongst matching record comparisons, 96.03% of records are in the exact match comparison level", "u_probability_description": "Amongst non-matching record comparisons, 0.55% of records are in the exact match comparison level", "has_tf_adjustments": false, "tf_adjustment_column": null, "tf_adjustment_weight": 1.0, "is_null_level": false, "bayes_factor": 175.06948423620076, "log2_bayes_factor": 7.45178382421554, "comparison_vector_value": 2, "max_comparison_vector_value": 2, "bayes_factor_description": "If comparison level is `exact match` then comparison is 175.07 times more likely to be a match", "probability_two_random_records_ ...

# %% [markdown]
# # Step 4 - Match Classification

# %%
# Predict matches and convert to dataframe

results = linker.predict(threshold_match_probability=0.99)
pres = results.as_pandas_dataframe()
pres = pres.merge(df_psc, left_on=['unique_id_l'], right_on=['unique_id'])
pres = pres.rename(columns={"Firstname_l": "Firstname_psc", "Lastname_l": "Lastname_psc", "Firstname_r":"Firstname_w", "Lastname_r":"Lastname_w"})
pres = pres[['match_weight','match_probability','Firstname_psc','Firstname_w', 'Lastname_psc','Lastname_w','company_number']]
pres
# Out:
#      match_weight  match_probability Firstname_psc Firstname_w Lastname_psc  \
# 0       12.558151           0.999834         Jamie       Jamie       Wallis
# 1       12.638040           0.999843         Peter       Peter       Gibson
# 2       14.787390           0.999965          Jack        Jack       Dromey
# 3       13.799580           0.999930       Stephen     Stephen        Timms
# 4       12.972798           0.999876         Craig       Craig    Whittaker
# ..            ...                ...           ...         ...          ...
# 337     12.419389           0.999817         James       James       Davies
# 338     14.302048           0.999950         David       David        Jones
# 339     11.719844           0.999704       Anthony     Anthony        Brown
# 340     12.972798           0.999876         Craig       Craig    Whittaker
# 341     12.618683           0.999841        Andrea      Andrea      Jenkyns
#
#     Lastname_w company_number
# 0       Wallis       08134008
# 1       Gibson       06301682
# 2       Dromey       10277215
# 3        Timms       01333367
# 4    Whittaker       10284374
# ..         ...            ...
# 337     Davies       12010734
# 338      Jones       12011911
# 339     Browne       12521856
# 340  Whittaker       14750574
# 341    Jenkyns       14768689
#
# [342 rows x 7 columns]

# %%
# Select matches that aren't exact

pres[(pres['Lastname_psc']!=pres['Lastname_w']) | (pres['Firstname_psc']!=pres['Firstname_w'])]
# Out:
#      match_weight  match_probability Firstname_psc Firstname_w Lastname_psc  \
# 5       11.668858           0.999693       Richard     Richard       Thomas
# 6       13.514815           0.999915          John        John    Mcdonnell
# 7       11.100448           0.999545         James       Jamie        Stone
# 8        9.983912           0.999013       Jeffrey        Jeff        Smith
# 15       9.983912           0.999013       Jeffrey        Jeff        Smith
# ..            ...                ...           ...         ...          ...
# 319     11.917547           0.999742          Mark        Mark      Gardner
# 322      8.767288           0.997710         Johan        John      Glennmo
# 327      9.681758           0.998784      Theodora        Theo       Clarke
# 331      8.767288           0.997710         Johan        John      Glennmo
# 339     11.719844           0.999704       Anthony     Anthony        Brown
#
#     Lastname_w company_number
# 5      Thomson       10609747
# 6    McDonnell       05350064
# 7        Stone       SC042883
# 8        Smith       09530115
# 15       Smith       13311041
# ..         ...            ...
# 319    Garnier       06540656
# 322       Glen       12254404
# 327     Clarke       08140289
# 331       Glen       14106498
# 339     Browne       12521856
#
# [80 rows x 7 columns]

# %%
pres.to_csv('pres.csv', index=False)

# %%
nonexact = pres[(pres['Lastname_psc']!=pres['Lastname_w']) | (pres['Firstname_psc']!=pres['Firstname_w'])]

# %%
nonexact.to_csv('nonexact.csv', index=False)
